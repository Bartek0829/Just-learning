# %% [markdown]
# # Python pandas liblary

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
high_paid_analysts = df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg > 100000)]

# %%
high_paid_analysts.head(20)
# Out:
#      job_title_short  ...                                    job_type_skills
# 410     Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'visio', '...
# 1555    Data Analyst  ...  {'cloud': ['databricks'], 'libraries': ['spark']}
# 1681    Data Analyst  ...  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 1684    Data Analyst  ...  {'cloud': ['azure', 'databricks'], 'os': ['lin...
# 1867    Data Analyst  ...  {'programming': ['php', 'python'], 'webframewo...
# 2818    Data Analyst  ...                        {'programming': ['python']}
# 3237    Data Analyst  ...  {'analyst_tools': ['visio', 'outlook', 'word',...
# 3457    Data Analyst  ...  {'libraries': ['numpy', 'pandas'], 'programmin...
# 3588    Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 3807    Data Analyst  ...  {'analyst_tools': ['ssrs', 'ssis'], 'databases...
# 3959    Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'outlook']...
# 4681    Data Analyst  ...   {'cloud': ['snowflake'], 'programming': ['sql']}
# 4728    Data Analyst  ...  {'analyst_tools': ['sas'], 'programming': ['sa...
# 4948    Data Analyst  ...  {'programming': ['sql'], 'webframeworks': ['ex...
# 4965    Data Analyst  ...  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 5167    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
# 7001    Data Analyst  ...  {'programming': ['sql', 'python', 'r'], 'webfr...
# 7178    Data Analyst  ...  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 7292    Data Analyst  ...  {'libraries': ['hadoop', 'spark'], 'other': ['...
# 7350    Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
#
# [20 rows x 17 columns]

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB
